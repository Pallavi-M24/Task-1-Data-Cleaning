# %%
import pandas as pd

df = pd.read_csv("Downloads/archive/Mall_Customers.csv")

print("=== BEFORE CLEANING ===")

print("\nDataset Info:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Cleaned dataset saved successfully!
